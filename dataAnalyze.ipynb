# %% [markdown]
# parameter1-10 plot

# %%
import seaborn as sns
import pandas as pd
import numpy as np

train = pd.read_csv('data/first_round_training_data.csv')
feature_name_param = ['Parameter{0}'.format(i) for i in range(1,11)]

df_param = np.log1p(train[feature_name_param])
h = df_param.hist(bins=100,figsize=(16,16),xlabelsize='10',ylabelsize='10',xrot=-15)
sns.despine(left=True, bottom=True)
[x.title.set_size(12) for x in h.ravel()]
[x.yaxis.tick_left() for x in h.ravel()]
# Out:
# [None, None, None, None, None, None, None, None, None, None, None, None]

# %% [markdown]
# Conclusion:

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

sns.set(style="ticks")
feature_name_param=['Parameter{0}'.format(i) for i in range(1,11)]
train = pd.read_csv('data/first_round_training_data.csv')
train_param = train[feature_name_param]
# print(train_param)
train_param_log1p = np.log1p(np.asarray(train_param))
print(train_param_log1p)
f, axes = plt.subplots(4, 3,figsize=(16,16))
# sns.despine(left=True, bottom=True)
sns.distplot(train_param_log1p[0],ax=axes[0,0],axlabel="param1")
sns.distplot(train_param_log1p[1],ax=axes[0,1],axlabel="param2")
sns.distplot(train_param_log1p[2],ax=axes[0,2],axlabel="param3")
sns.distplot(train_param_log1p[3],ax=axes[1,0],axlabel="param4")
sns.distplot(train_param_log1p[4],ax=axes[1,1],axlabel="param5")
sns.distplot(train_param_log1p[5],ax=axes[1,2],axlabel="param6")
sns.distplot(train_param_log1p[6],ax=axes[2,0],axlabel="param7")
sns.distplot(train_param_log1p[7],ax=axes[2,1],axlabel="param8")
sns.distplot(train_param_log1p[8],ax=axes[2,2],axlabel="param9")
sns.distplot(train_param_log1p[9],ax=axes[3,0],axlabel="param10")
# Out:
# [[1.65874415e-03 4.64371026e-01 5.00131447e+00 ... 3.47947515e-02
#   4.65670020e-01 6.98326231e-01]
#  [9.56183892e-01 1.49395326e-02 3.52362888e-02 ... 3.47947515e-02
#   4.65670020e-01 6.98326231e-01]
#  [9.35256465e-02 4.25182803e+00 7.78127707e-02 ... 3.47947515e-02
#   4.65670020e-01 6.98326231e-01]
#  ...
#  [3.36758739e-01 9.31074379e-02 5.78996643e-03 ... 3.47947515e-02
#   4.65670020e-01 1.08123908e+00]
#  [1.25352095e-01 1.32636733e-02 1.48070337e+00 ... 3.47947515e-02
#   4.65670020e-01 1.08123908e+00]
#  [3.69307253e+00 3.86990143e+00 8.69445460e-01 ... 3.47947515e-02
#   4.65670020e-01 1.08123908e+00]]

# %%
import seaborn as sns
import pandas as pd
import numpy as np

train = pd.read_csv('data/first_round_training_data.csv')
feature_name_attr = ['Attribute{0}'.format(i) for i in range(1,11)]

df_attr = np.log1p(train[feature_name_attr])
h = df_attr.hist(bins=100,figsize=(16,16),xlabelsize='10',ylabelsize='10',xrot=-15)
sns.despine(left=True, bottom=True)
[x.title.set_size(2) for x in h.ravel()]
[x.yaxis.tick_left() for x in h.ravel()]
# Out:
# [None, None, None, None, None, None, None, None, None, None, None, None]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

sns.set(style="ticks")
feature_name_attr=['Attribute{0}'.format(i) for i in range(1,11)]
train = pd.read_csv('data/first_round_training_data.csv')

train = np.log1p(train[feature_name_attr])

f, axes = plt.subplots(4, 3,figsize=(16,16))
# sns.despine(left=True, bottom=True)
sns.distplot(train['Attribute1'],ax=axes[0,0])
sns.distplot(train['Attribute2'],ax=axes[0,1])
sns.distplot(train['Attribute3'],ax=axes[0,2])
sns.distplot(train['Attribute4'],ax=axes[1,0])
sns.distplot(train['Attribute5'],ax=axes[1,1])
sns.distplot(train['Attribute6'],ax=axes[1,2])
sns.distplot(train['Attribute7'],ax=axes[2,0])
sns.distplot(train['Attribute8'],ax=axes[2,1])
sns.distplot(train['Attribute9'],ax=axes[2,2])
sns.distplot(train['Attribute10'],ax=axes[3,0])

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
feature_name_attr = ['Attribute{0}'.format(i) for i in range(1,11)]
feature_name_param = ['Parameter{0}'.format(i) for i in range(1,11)]
features = feature_name_attr + feature_name_param
df = pd.read_csv('data/first_round_training_data.csv')

mask = np.zeros_like(df[features].corr(), dtype=np.bool) 
mask[np.triu_indices_from(mask)] = True 

f, ax = plt.subplots(figsize=(16, 12))
plt.title('Pearson Correlation Matrix',fontsize=25)

sns.heatmap(df[features].corr(),linewidths=0.25,vmax=0.7,square=True,cmap="BuGn", #"BuGn_r" to reverse 
            linecolor='w',annot=True,annot_kws={"size":8},mask=mask,cbar_kws={"shrink": .9})
