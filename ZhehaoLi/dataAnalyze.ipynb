# %% [markdown]
# parameter1-10 plot

# %%
import seaborn as sns
import pandas as pd

train = pd.read_csv('data/first_round_training_data.csv')
feature_name_param = ['Parameter{0}'.format(i) for i in range(1,11)]

df_param = train[feature_name_param]
h = df_param.hist(bins=25,figsize=(16,16),xlabelsize='10',ylabelsize='10',xrot=-15)
sns.despine(left=True, bottom=True)
[x.title.set_size(12) for x in h.ravel()]
[x.yaxis.tick_left() for x in h.ravel()]

df_attr = train[feature_name_attr]

# %% [markdown]
# Conclusion:

# %%
import seaborn as sns
import pandas as pd

train = pd.read_csv('data/first_round_training_data.csv')
feature_name_attr = ['Attribute{0}'.format(i) for i in range(1,11)]

df_attr = train[feature_name_attr]
h = df_attr.hist(bins=25,figsize=(16,16),xlabelsize='10',ylabelsize='10',xrot=-15)
sns.despine(left=True, bottom=True)
[x.title.set_size(2) for x in h.ravel()]
[x.yaxis.tick_left() for x in h.ravel()]
# Out:
# [None, None, None, None, None, None, None, None, None, None, None, None]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
sns.set(style="whitegrid", font_scale=1)
feature_name_param = ['Parameter{0}'.format(i) for i in range(1,6)]
train = pd.read_csv('data/first_round_training_data.csv')
df_param = train[feature_name_param]
sns.boxplot(data=df_param)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
sns.set(style="whitegrid", font_scale=1)
feature_name_param = ['Parameter{0}'.format(i) for i in range(6,11)]
train = pd.read_csv('data/first_round_training_data.csv')
df_param = train[feature_name_param]
sns.boxplot(data=df_param)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
sns.set(style="whitegrid", font_scale=1)
# feature_name_attr = ['Attribute{0}'.format(i) for i in range(1,4)]
feature_name_attr=['Attribute3']
train = pd.read_csv('data/first_round_training_data.csv')
df_attr = train[feature_name_attr]
sns.boxplot(data=df_attr)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
feature_name_attr = ['Attribute{0}'.format(i) for i in range(1,11)]
feature_name_param = ['Parameter{0}'.format(i) for i in range(1,11)]
features = feature_name_attr + feature_name_param
df = pd.read_csv('data/first_round_training_data.csv')

mask = np.zeros_like(df[features].corr(), dtype=np.bool) 
mask[np.triu_indices_from(mask)] = True 

f, ax = plt.subplots(figsize=(16, 12))
plt.title('Pearson Correlation Matrix',fontsize=25)

sns.heatmap(df[features].corr(),linewidths=0.25,vmax=0.7,square=True,cmap="BuGn", #"BuGn_r" to reverse 
            linecolor='w',annot=True,annot_kws={"size":8},mask=mask,cbar_kws={"shrink": .9})
